# %%
notas = [10, 9, 13, 14, 19]

maior_nota = max(notas)
menor_nota = min(notas)

print("Maior nota:", maior_nota)
print("Menor nota", menor_nota)
# Out:
# Maior nota: 19
# Menor nota 9

# %%
print("Lista de notas:")
for nota in notas:
    print(nota)
# Out:
# Lista de notas:
# 10
# 9
# 13
# 14
# 19

# %%
def media_notas(lista):
    soma = sum(lista)
    media = soma / len(lista)
    return media

    print("Media das notas:", media_notas(notas))

# %%
numeros = [9, 4, 8, 10]
for numero in numeros:
    numeros append(numero + 2)
    print(y)
# Out:
#   Cell In[1], line 3
#     y append(numero + 2)
#       ^
# SyntaxError: invalid syntax
